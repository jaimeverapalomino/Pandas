# %% [markdown]
# ### Pandas documentation links
#
# * https://pandas.pydata.org/docs/index.html
# * https://pandas.pydata.org/docs/reference/frame.html

# %% [markdown]
# ***
# ### Libraries

# %% [markdown]
# import pandas as pd
# import numpy as np
# from glob import glob
# import os

# %% [markdown]
# ***
# ### Importing Excel Files into a Pandas DataFrame
#
# **Important Options:**
# * **io:** A string containing the pathname of the given Excel file.
# * **sheet_name:** The Excel sheet name, or sheet number, of the data you want to import. The sheet number can be an integer where 0 is the first sheet, 1 is the second, etc. If a list of sheet names/numbers are given, then the output will be a dictionary of DataFrames. The default is to read all the sheets and output a dictionary of DataFrames.
# * **header:** Row number to use for the list of column labels. The default is 0, indicating that the first row is assumed to contain the column labels. If the data does not have a row of column labels, None should be used.
# * **names:** A separate Python list input of column names. This option is None by default. This option is the equivalent of assigning a list of column names to the columns attribute of the output DataFrame.
# * **index_col:** Specifies which column should be used for row indices. The default option is None, meaning that all columns are included in the data, and a range of numbers is used as the row indices.
# * **usecols:** An integer, list of integers, or string that specifies the columns to be imported into the DataFrame. The default is to import all columns. If a string is given, then Pandas uses the standard Excel format to select columns (e.g. "A:C,F,G" will import columns A, B, C, F, and G).
# * **skiprows:** The number of rows to skip at the top of the Excel sheet. Default is 0. This option is useful for skipping rows in Excel that contain explanatory information about the data below it.

# %%
arch = os.listdir('/home/jovyan/work/Excel con Pandas')
arch
# Out:
# ['iris_data_set.xlsx', 'Excel con Pandas.ipynb', '.ipynb_checkpoints']

# %%
filename = '/home/jovyan/work/Excel con Pandas/iris_data_set.xlsx'

df = pd.read_excel(filename)
print(df)
# Out:
#      sepal length   sepal width  petal length  petal width           class
# 0              5.1          3.5           1.4          0.2     Iris-setosa
# 1              4.9          3.0           1.4          0.2     Iris-setosa
# 2              4.7          3.2           1.3          0.2     Iris-setosa
# 3              4.6          3.1           1.5          0.2     Iris-setosa
# 4              5.0          3.6           1.4          0.2     Iris-setosa
# ..             ...          ...           ...          ...             ...
# 145            6.7          3.0           5.2          2.3  Iris-virginica
# 146            6.3          2.5           5.0          1.9  Iris-virginica
# 147            6.5          3.0           5.2          2.0  Iris-virginica
# 148            6.2          3.4           5.4          2.3  Iris-virginica
# 149            5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ***
# ### Getting the name of all columns

# %%
df.columns
# Out:
# Index(['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class'], dtype='object')

# %% [markdown]
# ***
# ### Rename columns w/ spaces

# %%
df.columns = df.columns.str.replace(' ', '') 
print(df)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ***
# ### Dataframe INFO
#
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepallength  150 non-null    float64
#  1   sepalwidth   150 non-null    float64
#  2   petallength  150 non-null    float64
#  3   petalwidth   150 non-null    float64
#  4   class        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ***
# ### Dataframe Shape
#
# Return a tuple representing the dimensionality of the DataFrame

# %%
df.shape
# Out:
# (150, 5)

# %%
print('Total rows in Dataframe is: ',  df.shape[0])
print('Total columns in Dataframe is: ',  df.shape[1])
# Out:
# Total rows in Dataframe is:  150
# Total columns in Dataframe is:  5

# %% [markdown]
# ***
# ### Datatypes in Dataframe

# %%
df.dtypes
# Out:
# sepallength    float64
# sepalwidth     float64
# petallength    float64
# petalwidth     float64
# class           object
# dtype: object

# %%
print('Datatype for first columnn is: ',  df.dtypes[0])
print('Datatype for last columnn is: ',  df.dtypes[4])
# Out:
# Datatype for first columnn is:  float64
# Datatype for last columnn is:  object

# %% [markdown]
# ***

# %% [markdown]
# ### Import a specifc sheet

# %% [markdown]
# df = pd.read_excel(filename,sheet_name='Description')
# print(df)

# %% [markdown]
# ***
# ### Using a column from the sheet as an Index

# %%
df = pd.read_excel(filename,sheet_name='Data', index_col=0)
print(df)
# Out:
#                sepal width  petal length  petal width           class
# sepal length
# 5.1                    3.5           1.4          0.2     Iris-setosa
# 4.9                    3.0           1.4          0.2     Iris-setosa
# 4.7                    3.2           1.3          0.2     Iris-setosa
# 4.6                    3.1           1.5          0.2     Iris-setosa
# 5.0                    3.6           1.4          0.2     Iris-setosa
# ...                    ...           ...          ...             ...
# 6.7                    3.0           5.2          2.3  Iris-virginica
# 6.3                    2.5           5.0          1.9  Iris-virginica
# 6.5                    3.0           5.2          2.0  Iris-virginica
# 6.2                    3.4           5.4          2.3  Iris-virginica
# 5.9                    3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ***
# ### Skip rows and columns

# %%
df = pd.read_excel(filename, sheet_name='Data', header=None, skiprows=1, index_col=0)
print(df)
# Out:
#        1    2    3               4
# 0
# 5.1  3.5  1.4  0.2     Iris-setosa
# 4.9  3.0  1.4  0.2     Iris-setosa
# 4.7  3.2  1.3  0.2     Iris-setosa
# 4.6  3.1  1.5  0.2     Iris-setosa
# 5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...             ...
# 6.7  3.0  5.2  2.3  Iris-virginica
# 6.3  2.5  5.0  1.9  Iris-virginica
# 6.5  3.0  5.2  2.0  Iris-virginica
# 6.2  3.4  5.4  2.3  Iris-virginica
# 5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ***
# ### Import a specifc column(s)

# %%
df = pd.read_excel(filename, sheet_name='Data', header=None, skiprows=1, usecols='B,D')
print(df)
# Out:
#        1    3
# 0    3.5  0.2
# 1    3.0  0.2
# 2    3.2  0.2
# 3    3.1  0.2
# 4    3.6  0.2
# ..   ...  ...
# 145  3.0  2.3
# 146  2.5  1.9
# 147  3.0  2.0
# 148  3.4  2.3
# 149  3.0  1.8
#
# [150 rows x 2 columns]

# %% [markdown]
# ***
# ###  HEAD vs TAIL
#
# * Head = first N elements
# * Tail = last N elements

# %%
df.head(5)
# Out:
#      1    3
# 0  3.5  0.2
# 1  3.0  0.2
# 2  3.2  0.2
# 3  3.1  0.2
# 4  3.6  0.2

# %%
df.tail(5)
# Out:
#        1    3
# 145  3.0  2.3
# 146  2.5  1.9
# 147  3.0  2.0
# 148  3.4  2.3
# 149  3.0  1.8

# %% [markdown]
# ***
# ### View specific column's data

# %%
filename = '/home/jovyan/work/Excel con Pandas/iris_data_set.xlsx'
df = pd.read_excel(filename)
df.columns = df.columns.str.replace(' ', '') 
print(df)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['sepallength'].head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepallength, dtype: float64

# %% [markdown]
# ***
# ### View a specific column
#
# Three main methods to select columns:
#
# * Use dot notation: e.g. data.column_name
# * Use numeric indexing and the iloc selector data.loc[:, 'column_number']
# * Use square braces and the name of the column:, e.g. data['column_name']

# %%
df['class'].head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: class, dtype: object

# %%
df.iloc[:,[4]].head()
# Out:
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
df.loc[:,['class']].head()
# Out:
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# ***
# ### View multiple columns

# %%
df[['class', 'petallength']].head()
# Out:
#          class  petallength
# 0  Iris-setosa          1.4
# 1  Iris-setosa          1.4
# 2  Iris-setosa          1.3
# 3  Iris-setosa          1.5
# 4  Iris-setosa          1.4

# %% [markdown]
# ***
# ### Pass columns like a list

# %%
SpecificColumnList = ['class', 'petallength']

df[SpecificColumnList].head()
# Out:
#          class  petallength
# 0  Iris-setosa          1.4
# 1  Iris-setosa          1.4
# 2  Iris-setosa          1.3
# 3  Iris-setosa          1.5
# 4  Iris-setosa          1.4

# %% [markdown]
# ***
# ### View specific row's data

# %%
df.loc[20:30]
# Out:
#     sepallength  sepalwidth  petallength  petalwidth        class
# 20          5.4         3.4          1.7         0.2  Iris-setosa
# 21          5.1         3.7          1.5         0.4  Iris-setosa
# 22          4.6         3.6          1.0         0.2  Iris-setosa
# 23          5.1         3.3          1.7         0.5  Iris-setosa
# 24          4.8         3.4          1.9         0.2  Iris-setosa
# 25          5.0         3.0          1.6         0.2  Iris-setosa
# 26          5.0         3.4          1.6         0.4  Iris-setosa
# 27          5.2         3.5          1.5         0.2  Iris-setosa
# 28          5.2         3.4          1.4         0.2  Iris-setosa
# 29          4.7         3.2          1.6         0.2  Iris-setosa
# 30          4.8         3.1          1.6         0.2  Iris-setosa

# %% [markdown]
# ***
# ### Slice rows and columns together

# %%
df.loc[20:30, ['class']]
# Out:
#           class
# 20  Iris-setosa
# 21  Iris-setosa
# 22  Iris-setosa
# 23  Iris-setosa
# 24  Iris-setosa
# 25  Iris-setosa
# 26  Iris-setosa
# 27  Iris-setosa
# 28  Iris-setosa
# 29  Iris-setosa
# 30  Iris-setosa

# %% [markdown]
# ***
# ### Filter data in a column

# %%
df[df['class'] == 'Iris-versicolor'].head()
# Out:
#     sepallength  sepalwidth  petallength  petalwidth            class
# 50          7.0         3.2          4.7         1.4  Iris-versicolor
# 51          6.4         3.2          4.5         1.5  Iris-versicolor
# 52          6.9         3.1          4.9         1.5  Iris-versicolor
# 53          5.5         2.3          4.0         1.3  Iris-versicolor
# 54          6.5         2.8          4.6         1.5  Iris-versicolor

# %% [markdown]
# ***
# ### Filter multiple values

# %%
df[df['class'].isin(['Iris-versicolor', 'Iris-virginica'])]
# Out:
#      sepallength  sepalwidth  petallength  petalwidth            class
# 50           7.0         3.2          4.7         1.4  Iris-versicolor
# 51           6.4         3.2          4.5         1.5  Iris-versicolor
# 52           6.9         3.1          4.9         1.5  Iris-versicolor
# 53           5.5         2.3          4.0         1.3  Iris-versicolor
# 54           6.5         2.8          4.6         1.5  Iris-versicolor
# ..           ...         ...          ...         ...              ...
# 145          6.7         3.0          5.2         2.3   Iris-virginica
# 146          6.3         2.5          5.0         1.9   Iris-virginica
# 147          6.5         3.0          5.2         2.0   Iris-virginica
# 148          6.2         3.4          5.4         2.3   Iris-virginica
# 149          5.9         3.0          5.1         1.8   Iris-virginica
#
# [100 rows x 5 columns]

# %% [markdown]
# ***
# ### Filter multiple values using a list

# %%
Filter_Value = ['Iris-versicolor', 'Iris-virginica']

df[df['class'].isin(Filter_Value)]
# Out:
#      sepallength  sepalwidth  petallength  petalwidth            class
# 50           7.0         3.2          4.7         1.4  Iris-versicolor
# 51           6.4         3.2          4.5         1.5  Iris-versicolor
# 52           6.9         3.1          4.9         1.5  Iris-versicolor
# 53           5.5         2.3          4.0         1.3  Iris-versicolor
# 54           6.5         2.8          4.6         1.5  Iris-versicolor
# ..           ...         ...          ...         ...              ...
# 145          6.7         3.0          5.2         2.3   Iris-virginica
# 146          6.3         2.5          5.0         1.9   Iris-virginica
# 147          6.5         3.0          5.2         2.0   Iris-virginica
# 148          6.2         3.4          5.4         2.3   Iris-virginica
# 149          5.9         3.0          5.1         1.8   Iris-virginica
#
# [100 rows x 5 columns]

# %% [markdown]
# ***
# ### Filter values NOT in list or not equal to

# %%
Filter_Value = ['Iris-versicolor', 'Iris-virginica']

df[~df['class'].isin(Filter_Value)].head(5)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ***
# ### Filter using using multiple conditions in multiple columns

# %%
width = [2]
Flower_Name = ['Iris-setosa']

df[~df['class'].isin(Flower_Name) & df['petalwidth'].isin(width)]
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 110          6.5         3.2          5.1         2.0  Iris-virginica
# 113          5.7         2.5          5.0         2.0  Iris-virginica
# 121          5.6         2.8          4.9         2.0  Iris-virginica
# 122          7.7         2.8          6.7         2.0  Iris-virginica
# 131          7.9         3.8          6.4         2.0  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica

# %% [markdown]
# ***
# ### Filter using numeric conditions

# %%
df[df['sepallength'] == 5.1].head()
# Out:
#     sepallength  sepalwidth  petallength  petalwidth        class
# 0           5.1         3.5          1.4         0.2  Iris-setosa
# 17          5.1         3.5          1.4         0.3  Iris-setosa
# 19          5.1         3.8          1.5         0.3  Iris-setosa
# 21          5.1         3.7          1.5         0.4  Iris-setosa
# 23          5.1         3.3          1.7         0.5  Iris-setosa

# %%
df[df['sepallength'] > 5.1].head()
# Out:
#     sepallength  sepalwidth  petallength  petalwidth        class
# 5           5.4         3.9          1.7         0.4  Iris-setosa
# 10          5.4         3.7          1.5         0.2  Iris-setosa
# 14          5.8         4.0          1.2         0.2  Iris-setosa
# 15          5.7         4.4          1.5         0.4  Iris-setosa
# 16          5.4         3.9          1.3         0.4  Iris-setosa

# %% [markdown]
# ***
# ### Endswith function

# %%
df[df['class'].map(lambda x: x.endswith('setosa'))].head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ***
# ### Combine two filters to get the result

# %%
df[df['class'].map(lambda x: x.endswith('setosa')) & (df['sepallength'] > 5.1)].head()
# Out:
#     sepallength  sepalwidth  petallength  petalwidth        class
# 5           5.4         3.9          1.7         0.4  Iris-setosa
# 10          5.4         3.7          1.5         0.2  Iris-setosa
# 14          5.8         4.0          1.2         0.2  Iris-setosa
# 15          5.7         4.4          1.5         0.4  Iris-setosa
# 16          5.4         3.9          1.3         0.4  Iris-setosa

# %% [markdown]
# ***
# ### Contains function

# %%
df[df['class'].str.contains('set')].head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ***
# ### Get the unique values from dataframe

# %%
df['sepallength'].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
df.drop_duplicates(subset=['Name'])

# %%
df.drop_duplicates(subset=['Name']).iloc[:,[3,4]]

# %% [markdown]
# ***
# ### Sort Values

# %%
df.sort_values(by = ['sepallength'])
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 13           4.3         3.0          1.1         0.1     Iris-setosa
# 42           4.4         3.2          1.3         0.2     Iris-setosa
# 38           4.4         3.0          1.3         0.2     Iris-setosa
# 8            4.4         2.9          1.4         0.2     Iris-setosa
# 41           4.5         2.3          1.3         0.3     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 122          7.7         2.8          6.7         2.0  Iris-virginica
# 118          7.7         2.6          6.9         2.3  Iris-virginica
# 117          7.7         3.8          6.7         2.2  Iris-virginica
# 135          7.7         3.0          6.1         2.3  Iris-virginica
# 131          7.9         3.8          6.4         2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.sort_values(by = ['sepallength'], ascending = False)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 131          7.9         3.8          6.4         2.0  Iris-virginica
# 135          7.7         3.0          6.1         2.3  Iris-virginica
# 122          7.7         2.8          6.7         2.0  Iris-virginica
# 117          7.7         3.8          6.7         2.2  Iris-virginica
# 118          7.7         2.6          6.9         2.3  Iris-virginica
# ..           ...         ...          ...         ...             ...
# 41           4.5         2.3          1.3         0.3     Iris-setosa
# 42           4.4         3.2          1.3         0.2     Iris-setosa
# 38           4.4         3.0          1.3         0.2     Iris-setosa
# 8            4.4         2.9          1.4         0.2     Iris-setosa
# 13           4.3         3.0          1.1         0.1     Iris-setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# ***
# ### Describe method

# %%
df.describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
df.describe(include = ['object'])
# Out:
#                   class
# count               150
# unique                3
# top     Iris-versicolor
# freq                 50

# %%
df.describe(include = 'all')
# Out:
#         sepallength  sepalwidth  petallength  petalwidth            class
# count    150.000000  150.000000   150.000000  150.000000              150
# unique          NaN         NaN          NaN         NaN                3
# top             NaN         NaN          NaN         NaN  Iris-versicolor
# freq            NaN         NaN          NaN         NaN               50
# mean       5.843333    3.054000     3.758667    1.198667              NaN
# std        0.828066    0.433594     1.764420    0.763161              NaN
# min        4.300000    2.000000     1.000000    0.100000              NaN
# 25%        5.100000    2.800000     1.600000    0.300000              NaN
# 50%        5.800000    3.000000     4.350000    1.300000              NaN
# 75%        6.400000    3.300000     5.100000    1.800000              NaN
# max        7.900000    4.400000     6.900000    2.500000              NaN

# %% [markdown]
# ***
# ### Counting the unique values of a particular column

# %%
pd.value_counts(df['class'])
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: class, dtype: int64

# %% [markdown]
# ***
# ### Count cells

# %%
df.count(axis=0)
# Out:
# sepallength    150
# sepalwidth     150
# petallength    150
# petalwidth     150
# class          150
# dtype: int64

# %% [markdown]
# ***
# ### Sum Function

# %%
df.sum(axis = 0) # "0" suma por columnas
# Out:
# sepallength                                                876.5
# sepalwidth                                                 458.1
# petallength                                                563.8
# petalwidth                                                 179.8
# class          Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
df.sum(axis =1) # "1" suma por filas
# Out:
# 0      10.2
# 1       9.5
# 2       9.4
# 3       9.4
# 4      10.2
#        ...
# 145    17.2
# 146    15.7
# 147    16.7
# 148    17.3
# 149    15.8
# Length: 150, dtype: float64

# %% [markdown]
# ***
# ### Add a total column to the existing dataset

# %%
df['Total'] = df.sum(axis =1)

df.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class  Total
# 0          5.1         3.5          1.4         0.2  Iris-setosa   20.4
# 1          4.9         3.0          1.4         0.2  Iris-setosa   19.0
# 2          4.7         3.2          1.3         0.2  Iris-setosa   18.8
# 3          4.6         3.1          1.5         0.2  Iris-setosa   18.8
# 4          5.0         3.6          1.4         0.2  Iris-setosa   20.4

# %% [markdown]
# ***
# ### Sum of specific columns, use the loc method and pass the column names

# %%
df['Total_loc']=df.loc[:,['sepallength', 'sepalwidth']].sum(axis=1)

df.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class  Total  \
# 0          5.1         3.5          1.4         0.2  Iris-setosa   20.4
# 1          4.9         3.0          1.4         0.2  Iris-setosa   19.0
# 2          4.7         3.2          1.3         0.2  Iris-setosa   18.8
# 3          4.6         3.1          1.5         0.2  Iris-setosa   18.8
# 4          5.0         3.6          1.4         0.2  Iris-setosa   20.4
#
#    Total_loc
# 0        8.6
# 1        7.9
# 2        7.9
# 3        7.7
# 4        8.6

# %%
df['Total_DFSum']= df['sepallength'] + df['sepalwidth']

df.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class  Total  \
# 0          5.1         3.5          1.4         0.2  Iris-setosa   20.4
# 1          4.9         3.0          1.4         0.2  Iris-setosa   19.0
# 2          4.7         3.2          1.3         0.2  Iris-setosa   18.8
# 3          4.6         3.1          1.5         0.2  Iris-setosa   18.8
# 4          5.0         3.6          1.4         0.2  Iris-setosa   20.4
#
#    Total_loc  Total_DFSum
# 0        8.6          8.6
# 1        7.9          7.9
# 2        7.9          7.9
# 3        7.7          7.7
# 4        8.6          8.6

# %% [markdown]
# ***
# ### Adding sum-total beneath each column
#
# **Do the sum of columns**

# %%
Sum_Total = df[['sepallength', 'sepalwidth', 'Total']].sum()

Sum_Total
# Out:
# sepallength     876.5
# sepalwidth      458.1
# Total          4156.4
# dtype: float64

# %% [markdown]
# ###
#
# **Convert the series output to dataframe and transpose**

# %%
T_Sum = pd.DataFrame(data=Sum_Total).T

T_Sum
# Out:
#    sepallength  sepalwidth   Total
# 0        876.5       458.1  4156.4

# %% [markdown]
# ###
# **Re-index to add missing columns**

# %%
T_Sum = T_Sum.reindex(columns=df.columns)

T_Sum
# Out:
#    sepallength  sepalwidth  petallength  petalwidth  class   Total  Total_loc  \
# 0        876.5       458.1          NaN         NaN    NaN  4156.4        NaN
#
#    Total_DFSum
# 0          NaN

# %% [markdown]
# ###
# **append T_Sum to existing dataframe**

# %%
Row_Total = df.append(T_Sum,ignore_index=True)

Row_Total
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class   Total  \
# 0            5.1         3.5          1.4         0.2     Iris-setosa    20.4
# 1            4.9         3.0          1.4         0.2     Iris-setosa    19.0
# 2            4.7         3.2          1.3         0.2     Iris-setosa    18.8
# 3            4.6         3.1          1.5         0.2     Iris-setosa    18.8
# 4            5.0         3.6          1.4         0.2     Iris-setosa    20.4
# ..           ...         ...          ...         ...             ...     ...
# 146          6.3         2.5          5.0         1.9  Iris-virginica    31.4
# 147          6.5         3.0          5.2         2.0  Iris-virginica    33.4
# 148          6.2         3.4          5.4         2.3  Iris-virginica    34.6
# 149          5.9         3.0          5.1         1.8  Iris-virginica    31.6
# 150        876.5       458.1          NaN         NaN             NaN  4156.4
#
#      Total_loc  Total_DFSum
# 0          8.6          8.6
# 1          7.9          7.9
# 2          7.9          7.9
# 3          7.7          7.7
# 4          8.6          8.6
# ..         ...          ...
# 146        8.8          8.8
# 147        9.5          9.5
# 148        9.6          9.6
# 149        8.9          8.9
# 150        NaN          NaN
#
# [151 rows x 8 columns]

# %% [markdown]
# ***
# ### Sum based on criteria i.e. Sumif in Excel

# %%
df[df['class'] == 'Iris-versicolor'].sum()
# Out:
# sepallength                                                296.8
# sepalwidth                                                 138.5
# petallength                                                  213
# petalwidth                                                  66.3
# class          Iris-versicolorIris-versicolorIris-versicolorI...
# Total                                                     1429.2
# Total_loc                                                  435.3
# Total_DFSum                                                435.3
# dtype: object

# %% [markdown]
# ***
# ### Sumifs

# %%
df[df['class'].map(lambda x: x.endswith('sa')) & (df['sepallength'] > 5.1)].sum()
# Out:
# sepallength                                                 76.1
# sepalwidth                                                  52.9
# petallength                                                 20.7
# petalwidth                                                   3.6
# class          Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# Total                                                      306.6
# Total_loc                                                    129
# Total_DFSum                                                  129
# dtype: object

# %% [markdown]
# ***
# ### Averageif

# %%
df[df['class'] == 'Iris-versicolor'].mean()
# Out:
# sepallength     5.936
# sepalwidth      2.770
# petallength     4.260
# petalwidth      1.326
# Total          28.584
# Total_loc       8.706
# Total_DFSum     8.706
# dtype: float64

# %% [markdown]
# ***
# ### Averageifs

# %%
df[df['class'].map(lambda x: x.endswith('sa')) & (df['sepallength'] > 5.1)].mean()
# Out:
# sepallength     5.435714
# sepalwidth      3.778571
# petallength     1.478571
# petalwidth      0.257143
# Total          21.900000
# Total_loc       9.214286
# Total_DFSum     9.214286
# dtype: float64

# %% [markdown]
# ***
# ### Max

# %%
df[df['class'] == 'Iris-versicolor'].max()
# Out:
# sepallength                  7
# sepalwidth                 3.4
# petallength                5.1
# petalwidth                 1.8
# class          Iris-versicolor
# Total                     32.8
# Total_loc                 10.2
# Total_DFSum               10.2
# dtype: object

# %% [markdown]
# ***
# ### Min

# %%
df[df['class'] == 'Iris-versicolor'].min()
# Out:
# sepallength                4.9
# sepalwidth                   2
# petallength                  3
# petalwidth                   1
# class          Iris-versicolor
# Total                       23
# Total_loc                    7
# Total_DFSum                  7
# dtype: object

# %% [markdown]
# ***
# ### Groupby

# %%
df[['class','sepallength']].groupby('class').sum()
# Out:
#                  sepallength
# class
# Iris-setosa            250.3
# Iris-versicolor        296.8
# Iris-virginica         329.4

# %%
GroupBy = df.groupby('class').sum()

GroupBy.append(pd.DataFrame(df[['sepallength','sepalwidth','petallength','petalwidth']].sum()).T)
# Out:
#                  sepallength  sepalwidth  petallength  petalwidth   Total  \
# Iris-setosa            250.3       170.9         73.2        12.2  1013.2
# Iris-versicolor        296.8       138.5        213.0        66.3  1429.2
# Iris-virginica         329.4       148.7        277.6       101.3  1714.0
# 0                      876.5       458.1        563.8       179.8     NaN
#
#                  Total_loc  Total_DFSum
# Iris-setosa          421.2        421.2
# Iris-versicolor      435.3        435.3
# Iris-virginica       478.1        478.1
# 0                      NaN          NaN

# %% [markdown]
# ***
# ### Merge
#
# **Merge is used as an alternate which is same as SQL. There are a total of four merge options available:**
# * ‘left’ — Use the shared column from the left dataframe and match to right dataframe. Fill in any N/A as NaN
# * ‘right’ — Use the shared column from the right dataframe and match to left dataframe. Fill in any N/A as NaN
# * ‘inner’ — Only show data where the two shared columns overlap. Default method.
# * ‘outer’ — Return all records when there is a match in either left or right dataframe.

# %%
df1 = pd.read_excel(filename)

lookup = df.merge(df,on='class')
                  
lookup
# Out:
#       sepallength_x  sepalwidth_x  petallength_x  petalwidth_x  \
# 0               5.1           3.5            1.4           0.2
# 1               5.1           3.5            1.4           0.2
# 2               5.1           3.5            1.4           0.2
# 3               5.1           3.5            1.4           0.2
# 4               5.1           3.5            1.4           0.2
# ...             ...           ...            ...           ...
# 7495            5.9           3.0            5.1           1.8
# 7496            5.9           3.0            5.1           1.8
# 7497            5.9           3.0            5.1           1.8
# 7498            5.9           3.0            5.1           1.8
# 7499            5.9           3.0            5.1           1.8
#
#                class  Total_x  Total_loc_x  Total_DFSum_x  sepallength_y  \
# 0        Iris-setosa     20.4          8.6            8.6            5.1
# 1        Iris-setosa     20.4          8.6            8.6            4.9
# 2        Iris-setosa     20.4          8.6            8.6            4.7
# 3        Iris-setosa     20.4          8.6            8.6            4.6
# 4        Iris-setosa     20.4          8.6            8.6            5.0
# ...              ...      ...          ...            ...            ...
# 7495  Iris-virginica     31.6          8.9            8.9            6.7
# 7496  Iris-virginica     31.6          8.9            8.9            6.3
# 7497  Iris-virginica     31.6          8.9            8.9            6.5
# 7498  Iris-virginica     31.6          8.9            8.9            6.2
# 7499  Iris-virginica     31.6          8.9            8.9            5.9
#
#       sepalwidth_y  petallength_y  petalwidth_y  Total_y  Total_loc_y  \
# 0              3.5            1.4           0.2     20.4          8.6
# 1              3.0            1.4           0.2     19.0          7.9
# 2              3.2            1.3           0.2     18.8          7.9
# 3              3.1            1.5           0.2     18.8          7.7
# 4              3.6            1.4           0.2     20.4          8.6
# ...            ...            ...           ...      ...          ...
# 7495           3.0            5.2           2.3     34.4          9.7
# 7496           2.5            5.0           1.9     31.4          8.8
# 7497           3.0            5.2           2.0     33.4          9.5
# 7498           3.4            5.4           2.3     34.6          9.6
# 7499           3.0            5.1           1.8     31.6          8.9
#
#       Total_DFSum_y
# 0               8.6
# 1               7.9
# 2               7.9
# 3               7.7
# 4               8.6
# ...             ...
# 7495            9.7
# 7496            8.8
# 7497            9.5
# 7498            9.6
# 7499            8.9
#
# [7500 rows x 15 columns]

# %% [markdown]
# ***
# ### Pivot Tables

# %%
pd.pivot_table(df, index= 'class')
# Out:
#                   Total  Total_DFSum  Total_loc  petallength  petalwidth  \
# class
# Iris-setosa      20.264        8.424      8.424        1.464       0.244
# Iris-versicolor  28.584        8.706      8.706        4.260       1.326
# Iris-virginica   34.280        9.562      9.562        5.552       2.026
#
#                  sepallength  sepalwidth
# class
# Iris-setosa            5.006       3.418
# Iris-versicolor        5.936       2.770
# Iris-virginica         6.588       2.974

# %%
pd.pivot_table(df, values='sepalwidth', index= 'sepallength',columns='class', aggfunc = np.sum)
# Out:
# class        Iris-setosa  Iris-versicolor  Iris-virginica
# sepallength
# 4.3                  3.0              NaN             NaN
# 4.4                  9.1              NaN             NaN
# 4.5                  2.3              NaN             NaN
# 4.6                 13.3              NaN             NaN
# 4.7                  6.4              NaN             NaN
# 4.8                 15.9              NaN             NaN
# 4.9                 12.3              2.4             2.5
# 5.0                 26.9              4.3             NaN
# 5.1                 28.8              2.5             NaN
# 5.2                 11.0              2.7             NaN
# 5.3                  3.7              NaN             NaN
# 5.4                 18.3              3.0             NaN
# 5.5                  7.7             12.2             NaN
# 5.6                  NaN             14.1             2.8
# 5.7                  8.2             14.1             2.5
# 5.8                  4.0              8.0             8.2
# 5.9                  NaN              6.2             3.0
# 6.0                  NaN             11.2             5.2
# 6.1                  NaN             11.5             5.6
# 6.2                  NaN              5.1             6.2
# 6.3                  NaN              8.1            17.6
# 6.4                  NaN              6.1            14.6
# 6.5                  NaN              2.8            12.2
# 6.6                  NaN              5.9             NaN
# 6.7                  NaN              9.2            15.2
# 6.8                  NaN              2.8             6.2
# 6.9                  NaN              3.1             9.4
# 7.0                  NaN              3.2             NaN
# 7.1                  NaN              NaN             3.0
# 7.2                  NaN              NaN             9.8
# 7.3                  NaN              NaN             2.9
# 7.4                  NaN              NaN             2.8
# 7.6                  NaN              NaN             3.0
# 7.7                  NaN              NaN            12.2
# 7.9                  NaN              NaN             3.8

# %%
pd.pivot_table(df, values='sepalwidth', index= 'sepallength',columns='class', aggfunc = np.sum, fill_value=0)
# Out:
# class        Iris-setosa  Iris-versicolor  Iris-virginica
# sepallength
# 4.3                  3.0              0.0             0.0
# 4.4                  9.1              0.0             0.0
# 4.5                  2.3              0.0             0.0
# 4.6                 13.3              0.0             0.0
# 4.7                  6.4              0.0             0.0
# 4.8                 15.9              0.0             0.0
# 4.9                 12.3              2.4             2.5
# 5.0                 26.9              4.3             0.0
# 5.1                 28.8              2.5             0.0
# 5.2                 11.0              2.7             0.0
# 5.3                  3.7              0.0             0.0
# 5.4                 18.3              3.0             0.0
# 5.5                  7.7             12.2             0.0
# 5.6                  0.0             14.1             2.8
# 5.7                  8.2             14.1             2.5
# 5.8                  4.0              8.0             8.2
# 5.9                  0.0              6.2             3.0
# 6.0                  0.0             11.2             5.2
# 6.1                  0.0             11.5             5.6
# 6.2                  0.0              5.1             6.2
# 6.3                  0.0              8.1            17.6
# 6.4                  0.0              6.1            14.6
# 6.5                  0.0              2.8            12.2
# 6.6                  0.0              5.9             0.0
# 6.7                  0.0              9.2            15.2
# 6.8                  0.0              2.8             6.2
# 6.9                  0.0              3.1             9.4
# 7.0                  0.0              3.2             0.0
# 7.1                  0.0              0.0             3.0
# 7.2                  0.0              0.0             9.8
# 7.3                  0.0              0.0             2.9
# 7.4                  0.0              0.0             2.8
# 7.6                  0.0              0.0             3.0
# 7.7                  0.0              0.0            12.2
# 7.9                  0.0              0.0             3.8

# %%
pd.pivot_table(df, values=['sepalwidth', 'petalwidth'], index= 'sepallength',columns='class', aggfunc = np.sum, fill_value=0)
# Out:
#              petalwidth                                 sepalwidth  \
# class       Iris-setosa Iris-versicolor Iris-virginica Iris-setosa
# sepallength
# 4.3                 0.1             0.0            0.0         3.0
# 4.4                 0.6             0.0            0.0         9.1
# 4.5                 0.3             0.0            0.0         2.3
# 4.6                 0.9             0.0            0.0        13.3
# 4.7                 0.4             0.0            0.0         6.4
# 4.8                 1.0             0.0            0.0        15.9
# 4.9                 0.5             1.0            1.7        12.3
# 5.0                 2.3             2.0            0.0        26.9
# 5.1                 2.5             1.1            0.0        28.8
# 5.2                 0.5             1.4            0.0        11.0
# 5.3                 0.2             0.0            0.0         3.7
# 5.4                 1.6             1.5            0.0        18.3
# 5.5                 0.4             5.9            0.0         7.7
# 5.6                 0.0             6.5            2.0         0.0
# 5.7                 0.7             6.1            2.0         8.2
# 5.8                 0.2             3.4            6.2         4.0
# 5.9                 0.0             3.3            1.8         0.0
# 6.0                 0.0             5.7            3.3         0.0
# 6.1                 0.0             5.3            3.2         0.0
# 6.2                 0.0             2.8            4.1         0.0
# 6.3                 0.0             4.4           11.9         0.0
# 6.4                 0.0             2.8           10.3         0.0
# 6.5                 0.0             1.5            8.0         0.0
# 6.6                 0.0             2.7            0.0         0.0
# 6.7                 0.0             4.6           11.1         0.0
# 6.8                 0.0             1.4            4.4         0.0
# 6.9                 0.0             1.5            6.7         0.0
# 7.0                 0.0             1.4            0.0         0.0
# 7.1                 0.0             0.0            2.1         0.0
# 7.2                 0.0             0.0            5.9         0.0
# 7.3                 0.0             0.0            1.8         0.0
# 7.4                 0.0             0.0            1.9         0.0
# 7.6                 0.0             0.0            2.1         0.0
# 7.7                 0.0             0.0            8.8         0.0
# 7.9                 0.0             0.0            2.0         0.0
#
#
# class       Iris-versicolor Iris-virginica
# sepallength
# 4.3                     0.0            0.0
# 4.4                     0.0            0.0
# 4.5                     0.0            0.0
# 4.6                     0.0            0.0
# 4.7                     0.0            0.0
# 4.8                     0.0            0.0
# 4.9                     2.4            2.5
# 5.0                     4.3            0.0
# 5.1                     2.5            0.0
# 5.2                     2.7            0.0
# 5.3                     0.0            0.0
# 5.4                     3.0            0.0
# 5.5                    12.2            0.0
# 5.6                    14.1            2.8
# 5.7                    14.1            2.5
# 5.8                     8.0            8.2
# 5.9                     6.2            3.0
# 6.0                    11.2            5.2
# 6.1                    11.5            5.6
# 6.2                     5.1            6.2
# 6.3                     8.1           17.6
# 6.4                     6.1           14.6
# 6.5                     2.8           12.2
# 6.6                     5.9            0.0
# 6.7                     9.2           15.2
# 6.8                     2.8            6.2
# 6.9                     3.1            9.4
# 7.0                     3.2            0.0
# 7.1                     0.0            3.0
# 7.2                     0.0            9.8
# 7.3                     0.0            2.9
# 7.4                     0.0            2.8
# 7.6                     0.0            3.0
# 7.7                     0.0           12.2
# 7.9                     0.0            3.8

# %%
pd.pivot_table(df, values=['sepalwidth', 'petalwidth'], index= ['sepallength', 'petallength'],columns='class', aggfunc = np.sum, fill_value=0)
# Out:
#                          petalwidth                                 \
# class                   Iris-setosa Iris-versicolor Iris-virginica
# sepallength petallength
# 4.3         1.1                 0.1             0.0            0.0
# 4.4         1.3                 0.4             0.0            0.0
#             1.4                 0.2             0.0            0.0
# 4.5         1.3                 0.3             0.0            0.0
# 4.6         1.0                 0.2             0.0            0.0
# ...                             ...             ...            ...
# 7.6         6.6                 0.0             0.0            2.1
# 7.7         6.1                 0.0             0.0            2.3
#             6.7                 0.0             0.0            4.2
#             6.9                 0.0             0.0            2.3
# 7.9         6.4                 0.0             0.0            2.0
#
#                          sepalwidth
# class                   Iris-setosa Iris-versicolor Iris-virginica
# sepallength petallength
# 4.3         1.1                 3.0             0.0            0.0
# 4.4         1.3                 6.2             0.0            0.0
#             1.4                 2.9             0.0            0.0
# 4.5         1.3                 2.3             0.0            0.0
# 4.6         1.0                 3.6             0.0            0.0
# ...                             ...             ...            ...
# 7.6         6.6                 0.0             0.0            3.0
# 7.7         6.1                 0.0             0.0            3.0
#             6.7                 0.0             0.0            6.6
#             6.9                 0.0             0.0            2.6
# 7.9         6.4                 0.0             0.0            3.8
#
# [123 rows x 6 columns]

# %%
pd.pivot_table(df, values=['sepalwidth', 'petalwidth'], index= 'sepallength',columns='class', aggfunc = {'sepalwidth': np.sum, 'petalwidth': np.mean}, fill_value=0)
# Out:
#              petalwidth                                 sepalwidth  \
# class       Iris-setosa Iris-versicolor Iris-virginica Iris-setosa
# sepallength
# 4.3            0.100000        0.000000       0.000000         3.0
# 4.4            0.200000        0.000000       0.000000         9.1
# 4.5            0.300000        0.000000       0.000000         2.3
# 4.6            0.225000        0.000000       0.000000        13.3
# 4.7            0.200000        0.000000       0.000000         6.4
# 4.8            0.200000        0.000000       0.000000        15.9
# 4.9            0.125000        1.000000       1.700000        12.3
# 5.0            0.287500        1.000000       0.000000        26.9
# 5.1            0.312500        1.100000       0.000000        28.8
# 5.2            0.166667        1.400000       0.000000        11.0
# 5.3            0.200000        0.000000       0.000000         3.7
# 5.4            0.320000        1.500000       0.000000        18.3
# 5.5            0.200000        1.180000       0.000000         7.7
# 5.6            0.000000        1.300000       2.000000         0.0
# 5.7            0.350000        1.220000       2.000000         8.2
# 5.8            0.200000        1.133333       2.066667         4.0
# 5.9            0.000000        1.650000       1.800000         0.0
# 6.0            0.000000        1.425000       1.650000         0.0
# 6.1            0.000000        1.325000       1.600000         0.0
# 6.2            0.000000        1.400000       2.050000         0.0
# 6.3            0.000000        1.466667       1.983333         0.0
# 6.4            0.000000        1.400000       2.060000         0.0
# 6.5            0.000000        1.500000       2.000000         0.0
# 6.6            0.000000        1.350000       0.000000         0.0
# 6.7            0.000000        1.533333       2.220000         0.0
# 6.8            0.000000        1.400000       2.200000         0.0
# 6.9            0.000000        1.500000       2.233333         0.0
# 7.0            0.000000        1.400000       0.000000         0.0
# 7.1            0.000000        0.000000       2.100000         0.0
# 7.2            0.000000        0.000000       1.966667         0.0
# 7.3            0.000000        0.000000       1.800000         0.0
# 7.4            0.000000        0.000000       1.900000         0.0
# 7.6            0.000000        0.000000       2.100000         0.0
# 7.7            0.000000        0.000000       2.200000         0.0
# 7.9            0.000000        0.000000       2.000000         0.0
#
#
# class       Iris-versicolor Iris-virginica
# sepallength
# 4.3                     0.0            0.0
# 4.4                     0.0            0.0
# 4.5                     0.0            0.0
# 4.6                     0.0            0.0
# 4.7                     0.0            0.0
# 4.8                     0.0            0.0
# 4.9                     2.4            2.5
# 5.0                     4.3            0.0
# 5.1                     2.5            0.0
# 5.2                     2.7            0.0
# 5.3                     0.0            0.0
# 5.4                     3.0            0.0
# 5.5                    12.2            0.0
# 5.6                    14.1            2.8
# 5.7                    14.1            2.5
# 5.8                     8.0            8.2
# 5.9                     6.2            3.0
# 6.0                    11.2            5.2
# 6.1                    11.5            5.6
# 6.2                     5.1            6.2
# 6.3                     8.1           17.6
# 6.4                     6.1           14.6
# 6.5                     2.8           12.2
# 6.6                     5.9            0.0
# 6.7                     9.2           15.2
# 6.8                     2.8            6.2
# 6.9                     3.1            9.4
# 7.0                     3.2            0.0
# 7.1                     0.0            3.0
# 7.2                     0.0            9.8
# 7.3                     0.0            2.9
# 7.4                     0.0            2.8
# 7.6                     0.0            3.0
# 7.7                     0.0           12.2
# 7.9                     0.0            3.8

# %%
pd.pivot_table(df, values=['sepalwidth', 'petalwidth'], index= 'sepallength',columns='class', aggfunc = {'sepalwidth': np.sum, 'petalwidth': np.mean}, fill_value=0, margins=True)
# Out:
#              petalwidth                                           sepalwidth  \
# class       Iris-setosa Iris-versicolor Iris-virginica       All Iris-setosa
# sepallength
# 4.3            0.100000        0.000000       0.000000  0.100000         3.0
# 4.4            0.200000        0.000000       0.000000  0.200000         9.1
# 4.5            0.300000        0.000000       0.000000  0.300000         2.3
# 4.6            0.225000        0.000000       0.000000  0.225000        13.3
# 4.7            0.200000        0.000000       0.000000  0.200000         6.4
# 4.8            0.200000        0.000000       0.000000  0.200000        15.9
# 4.9            0.125000        1.000000       1.700000  0.533333        12.3
# 5.0            0.287500        1.000000       0.000000  0.430000        26.9
# 5.1            0.312500        1.100000       0.000000  0.400000        28.8
# 5.2            0.166667        1.400000       0.000000  0.475000        11.0
# 5.3            0.200000        0.000000       0.000000  0.200000         3.7
# 5.4            0.320000        1.500000       0.000000  0.516667        18.3
# 5.5            0.200000        1.180000       0.000000  0.900000         7.7
# 5.6            0.000000        1.300000       2.000000  1.416667         0.0
# 5.7            0.350000        1.220000       2.000000  1.100000         8.2
# 5.8            0.200000        1.133333       2.066667  1.400000         4.0
# 5.9            0.000000        1.650000       1.800000  1.700000         0.0
# 6.0            0.000000        1.425000       1.650000  1.500000         0.0
# 6.1            0.000000        1.325000       1.600000  1.416667         0.0
# 6.2            0.000000        1.400000       2.050000  1.725000         0.0
# 6.3            0.000000        1.466667       1.983333  1.811111         0.0
# 6.4            0.000000        1.400000       2.060000  1.871429         0.0
# 6.5            0.000000        1.500000       2.000000  1.900000         0.0
# 6.6            0.000000        1.350000       0.000000  1.350000         0.0
# 6.7            0.000000        1.533333       2.220000  1.962500         0.0
# 6.8            0.000000        1.400000       2.200000  1.933333         0.0
# 6.9            0.000000        1.500000       2.233333  2.050000         0.0
# 7.0            0.000000        1.400000       0.000000  1.400000         0.0
# 7.1            0.000000        0.000000       2.100000  2.100000         0.0
# 7.2            0.000000        0.000000       1.966667  1.966667         0.0
# 7.3            0.000000        0.000000       1.800000  1.800000         0.0
# 7.4            0.000000        0.000000       1.900000  1.900000         0.0
# 7.6            0.000000        0.000000       2.100000  2.100000         0.0
# 7.7            0.000000        0.000000       2.200000  2.200000         0.0
# 7.9            0.000000        0.000000       2.000000  2.000000         0.0
# All            0.244000        1.326000       2.026000  1.198667       170.9
#
#
# class       Iris-versicolor Iris-virginica    All
# sepallength
# 4.3                     0.0            0.0    3.0
# 4.4                     0.0            0.0    9.1
# 4.5                     0.0            0.0    2.3
# 4.6                     0.0            0.0   13.3
# 4.7                     0.0            0.0    6.4
# 4.8                     0.0            0.0   15.9
# 4.9                     2.4            2.5   17.2
# 5.0                     4.3            0.0   31.2
# 5.1                     2.5            0.0   31.3
# 5.2                     2.7            0.0   13.7
# 5.3                     0.0            0.0    3.7
# 5.4                     3.0            0.0   21.3
# 5.5                    12.2            0.0   19.9
# 5.6                    14.1            2.8   16.9
# 5.7                    14.1            2.5   24.8
# 5.8                     8.0            8.2   20.2
# 5.9                     6.2            3.0    9.2
# 6.0                    11.2            5.2   16.4
# 6.1                    11.5            5.6   17.1
# 6.2                     5.1            6.2   11.3
# 6.3                     8.1           17.6   25.7
# 6.4                     6.1           14.6   20.7
# 6.5                     2.8           12.2   15.0
# 6.6                     5.9            0.0    5.9
# 6.7                     9.2           15.2   24.4
# 6.8                     2.8            6.2    9.0
# 6.9                     3.1            9.4   12.5
# 7.0                     3.2            0.0    3.2
# 7.1                     0.0            3.0    3.0
# 7.2                     0.0            9.8    9.8
# 7.3                     0.0            2.9    2.9
# 7.4                     0.0            2.8    2.8
# 7.6                     0.0            3.0    3.0
# 7.7                     0.0           12.2   12.2
# 7.9                     0.0            3.8    3.8
# All                   138.5          148.7  458.1
