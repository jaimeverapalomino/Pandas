# %%
import pandas as pd

# %%
# %fs ls FileStore/tables/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/movie_sample_dataset.txt</td><td>movie_sample_dataset.txt</td><td>15326</td><td>1646961155000</td></tr><tr><td>dbfs:/FileStore/tables/sample_csv_file.csv</td><td>sample_csv_file.csv</td><td>33396236</td><td>1642807086000</td></tr><tr><td>dbfs:/FileStore/tables/test-1.csv</td><td>test-1.csv</td><td>28629</td><td>1647281721000</td></tr><tr><td>dbfs:/FileStore/tables/test.csv</td><td>test.csv</td><td>28629</td><td>1647281469000</td></tr></tbody></table></div>

# %%
dbutils.fs.cp("dbfs:/FileStore/tables/test.csv", "file:///tmp/test.csv")
# Out:
# Out[13]: True

# %%
df = pd.read_csv("file:///tmp/test.csv")
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>892</td>
#       <td>3</td>
#       <td>Kelly, Mr. James</td>
#       <td>male</td>
#       <td>34.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>330911</td>
#       <td>7.8292</td>
#       <td>NaN</td>
#       <td>Q</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>893</td>
# ...

# %%
#SELECT Name FROM df
print(df["Name"])
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
#SELECT * FROM df LIMIT 5
df.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>892</td>
#       <td>3</td>
#       <td>Kelly, Mr. James</td>
#       <td>male</td>
#       <td>34.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>330911</td>
#       <td>7.8292</td>
#       <td>NaN</td>
#       <td>Q</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>893</td>
# ...

# %%
#SELECT DISTINCT age FROM df
print(df["Age"].unique())
# Out:
# [34.5  47.   62.   27.   22.   14.   30.   26.   18.   21.     nan 46.
#  23.   63.   24.   35.   45.   55.    9.   48.   50.   22.5  41.   33.
#  18.5  25.   39.   60.   36.   20.   28.   10.   17.   32.   13.   31.
#  29.   28.5  32.5   6.   67.   49.    2.   76.   43.   16.    1.   12.
#  42.   53.   26.5  40.   61.   60.5   7.   15.   54.   64.   37.   34.
#  11.5   8.    0.33 38.   57.   40.5   0.92 19.   36.5   0.75  0.83 58.
#   0.17 59.   14.5  44.    5.   51.    3.   38.5 ]

# %%
#SELECT COUNT(DISTINCT Age) FROM df
print(len(df["Age"].unique()))
# Out:
# 80

# %%
#SELECT * FROM df WHERE Pclass = 1
df[df.Pclass == 1]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>11</th>
#       <td>903</td>
#       <td>1</td>
#       <td>Jones, Mr. Charles Cresson</td>
#       <td>male</td>
#       <td>46.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>694</td>
#       <td>26.0000</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>12</th>
# ...

# %%
#SELECT * FROM df WHERE Pclass = 1 OR pclass = 2
df[(df.Pclass == 1) | (df.Pclass == 2)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>894</td>
#       <td>2</td>
#       <td>Myles, Mr. Thomas Francis</td>
#       <td>male</td>
#       <td>62.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>240276</td>
#       <td>9.6875</td>
#       <td>NaN</td>
#       <td>Q</td>
#     </tr>
#     <tr>
#       <th>7</th>
# ...

# %%
#SELECT * FROM df WHERE Pclass IN (1,2)
df[df.Pclass.isin([1,2])]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>894</td>
#       <td>2</td>
#       <td>Myles, Mr. Thomas Francis</td>
#       <td>male</td>
#       <td>62.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>240276</td>
#       <td>9.6875</td>
#       <td>NaN</td>
#       <td>Q</td>
#     </tr>
#     <tr>
#       <th>7</th>
# ...

# %%
#SELECT Name FROM df WHERE Pclass = 1 AND Sex = "male"
print(df[(df.Pclass == 1) & (df.Sex == "male")]["Name"])
# Out:
# 11                            Jones, Mr. Charles Cresson
# 20                                Rothschild, Mr. Martin
# 23                       Williams, Mr. Richard Norris II
# 28                               Brady, Mr. John Bertram
# 34                              Mock, Mr. Philipp Edmund
# 41                           Franklin, Mr. Thomas Parham
# 46                              Chevre, Mr. Paul Romaine
# 50                              Smith, Mr. Lucien Philip
# 64                           Ryerson, Master. John Borie
# 67                        Moore, Mr. Clarence Bloomfield
# 68                       Tucker, Mr. Gilbert Milligan Jr
# 73                       Ovies y Rodriguez, Mr. Servando
# 75                                    Keeping, Mr. Edwin
# 81                                    Straus, Mr. Isidor
# 82                                Case, Mr. Howard Brown
# 94                                   Birnbaum, Mr. Jakob
# ...

# %%
#SELECT Name, Name FROM df WHERE pclass NOT IN (1,2)
df[~titanic_df.Pclass.isin([1,2])][["Name","Name"]]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Kelly, Mr. James</td>
#       <td>34.5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Wilkes, Mrs. James (Ellen Needs)</td>
#       <td>47.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Wirz, Mr. Albert</td>
#       <td>27.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Hirvonen, Mrs. Alexander (Helga E Lindqvist)</td>
#       <td>22.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Svensson, Mr. Johan Cervin</td>
#       <td>14.0</td>
#     </tr>
# ...

# %%
#SELECT Pclass, Sex, COUNT(*) FROM df GROUP BY 1,2
df.groupby(["Pclass","Sex"]).size()
# Out:
# Out[54]: Pclass  Sex
# 1       female     50
#         male       57
# 2       female     30
#         male       63
# 3       female     72
#         male      146
# dtype: int64

# %%
#SELECT Pclass, Sex, COUNT(*) FROM df GROUP BY 1,2 ORDER BY 3 DESC
df.groupby(["Pclass","Sex"]).size().sort_values(ascending=False)
# Out:
# Out[55]: Pclass  Sex
# 3       male      146
#         female     72
# 2       male       63
# 1       male       57
#         female     50
# 2       female     30
# dtype: int64

# %%
#SELECT Name, Pclass, Sex FROM df ORDER BY 1, 2 DESC
df.sort_values(["Name","Pclass"],ascending=[True,False])[["Name","Pclass","Sex"]]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Pclass</th>
#       <th>Sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>392</th>
#       <td>Abbott, Master. Eugene Joseph</td>
#       <td>3</td>
#       <td>male</td>
#     </tr>
#     <tr>
#       <th>345</th>
#       <td>Abelseth, Miss. Karen Marie</td>
#       <td>3</td>
#       <td>female</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>Abelseth, Mr. Olaus Jorgensen</td>
#       <td>3</td>
#       <td>male</td>
#     </tr>
#     <tr>
#       <th>251</th>
#       <td>Abrahamsson, Mr. Abraham August Johannes</td>
#       <td>3</td>
#       <td>male</td>
# ...

# %%
#SELECT Pclass, Sex, SUM(Fare) FROM df GROUP BY 1,2
df.groupby(["Pclass","Sex"]).sum()["Fare"]
# Out:
# Out[57]: Pclass  Sex
# 1       female    5779.5584
#         male      4308.4334
# 2       female     793.1625
#         male      1271.6332
# 3       female     988.9293
#         male      1714.8208
# Name: Fare, dtype: float64

# %%
#SELECT MIN(age) AS min, MAX(age) AS max, AVG(age) AS mean, APPROX_QUANTILES(age, 100)[OFFSET(50)] AS median
#FROM titanic_test_data
df.agg({'Age': ['min', 'max', 'mean', 'median']})
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>min</th>
#       <td>0.17000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>76.00000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>30.27259</td>
#     </tr>
#     <tr>
#       <th>median</th>
#       <td>27.00000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
